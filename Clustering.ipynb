# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from scipy.cluster import hierarchy
import random
from sklearn.metrics import silhouette_score, completeness_score

# %% [markdown]
# # Clustering with Given Features

# %%
# Read the feature data from CSV
data = pd.read_csv('features.csv')
X = data.iloc[:,:].values

# Perform clustering with different numbers of clusters
n_clusters = [2, 3, 6, 9, 50]

# GMM Clustering
for n in n_clusters:
    # Fit GMM to the data
    gmm = GaussianMixture(n_components=n)
    gmm.fit(X)

    # Predict cluster labels
    labels = gmm.predict(X)

    # Create a dictionary to store the cluster points
    cluster_points = {i: [] for i in range(n)}

    for i, label in enumerate(labels):
        cluster_points[label].append(i)

    # Print three random points from each cluster
    for cluster, points in cluster_points.items():
        random_points = random.sample(points, min(3, len(points)))
        print(f"Random points from GMM cluster {cluster}: {random_points}")

    # Calculate the Silhouette Coefficient
    silhouette_coefficient = silhouette_score(data, labels)
    print("Silhouette Coefficient:", silhouette_coefficient)

    # Apply PCA for visualization
    pca = PCA(n_components=2)
    X_pca = pca.fit_transform(X)

    # Plot the clusters
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis')
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.title(f'GMM Clustering with {n} clusters')
    plt.show()
# Out:
# Random points from GMM cluster 0: [2297, 550, 3084]
# Random points from GMM cluster 1: [1656, 3242, 1771]
# Silhouette Coefficient: 0.29573556596765077
# Random points from GMM cluster 0: [2131, 491, 403]
# Random points from GMM cluster 1: [2130, 2610, 3363]
# Random points from GMM cluster 2: [311, 2289, 663]
# Silhouette Coefficient: 0.2619747240899511
# Random points from GMM cluster 0: [3173, 1219, 1764]
# Random points from GMM cluster 1: [2072, 1544, 909]
# Random points from GMM cluster 2: [428, 2282, 3038]
# Random points from GMM cluster 3: [1345, 987, 2904]
# Random points from GMM cluster 4: [2610, 2150, 310]
# Random points from GMM cluster 5: [1535, 291, 2299]
# Silhouette Coefficient: 0.1934223763948324
# Random points from GMM cluster 0: [257, 2843, 3067]
# Random points from GMM cluster 1: [1923, 2946, 1617]
# Random points from GMM cluster 2: [49, 75, 2753]
# Random points from GMM cluster 3: [381, 1438, 2436]
# Random points from GMM cluster 4: [644, 2930, 1007]
# Random points from GMM cluster 5: [461, 792, 2766]
# Random points from GMM cluster 6: [2419, 699, 555]
# Random points from GMM cluster 7: [1171, 1683, 2831]
# Random points from GMM cluster 8: [309, 2534, 3065]
# Silhouette Coefficient: 0.19689536642848993
# Random points from GMM cluster 0: [3411, 2209, 1453]
# Random points from GMM cluster 1: [2033, 239, 608]
# Random points from GMM cluster 2: [1486, 1939, 1206]
# Random points from GMM cluster 3: [1831, 2006, 2062]
# Random points from GMM cluster 4: [672, 1708, 2913]
# Random points from GMM cluster 5: [2496, 2779, 1341]
# Random points from GMM cluster 6: [1468, 293, 2549]
# Random points from GMM cluster 7: [1275, 1541, 2677]
# Random points from GMM cluster 8: [988, 2415, 3215]
# Random points from GMM cluster 9: [2957, 3360, 460]
# Random points from GMM cluster 10: [277, 1861, 1423]
# Random points from GMM cluster 11: [2611, 1588, 2366]
# Random points from GMM cluster 12: [2229, 39, 2292]
# Random points from GMM cluster 13: [2203, 2568, 1756]
# Random points from GMM cluster 14: [1192, 975, 695]
# Random points from GMM cluster 15: [585, 1603, 454]
# Random points from GMM cluster 16: [825, 897, 1746]
# Random points from GMM cluster 17: [824, 56, 1894]
# Random points from GMM cluster 18: [408, 826, 1777]
# Random points from GMM cluster 19: [714, 1992, 1634]
# Random points from GMM cluster 20: [566, 2689, 1183]
# Random points from GMM cluster 21: [862, 658, 994]
# Random points from GMM cluster 22: [3166, 2348, 630]
# Random points from GMM cluster 23: [1689, 1303, 3217]
# Random points from GMM cluster 24: [1051, 1404, 2197]
# Random points from GMM cluster 25: [2720, 2121, 627]
# Random points from GMM cluster 26: [2548, 1131, 1851]
# Random points from GMM cluster 27: [867, 789, 1678]
# Random points from GMM cluster 28: [586, 2506, 2544]
# Random points from GMM cluster 29: [748, 3218, 1891]
# Random points from GMM cluster 30: [949, 553, 2206]
# Random points from GMM cluster 31: [273, 2803, 2810]
# Random points from GMM cluster 32: [1671, 1596, 3082]
# Random points from GMM cluster 33: [328, 240, 278]
# Random points from GMM cluster 34: [1903, 724, 3205]
# Random points from GMM cluster 35: [250, 3231, 104]
# Random points from GMM cluster 36: [2794, 3189, 1667]
# Random points from GMM cluster 37: [249, 2646, 2436]
# Random points from GMM cluster 38: [421, 2723, 2999]
# Random points from GMM cluster 39: [2817, 1639, 1236]
# Random points from GMM cluster 40: [3018, 2747, 232]
# Random points from GMM cluster 41: [2410, 2053, 3]
# Random points from GMM cluster 42: [2432, 1027, 1422]
# Random points from GMM cluster 43: [1060, 987, 908]
# Random points from GMM cluster 44: [3370, 101, 2086]
# Random points from GMM cluster 45: [28, 649, 2622]
# Random points from GMM cluster 46: [2369, 2481, 2748]
# Random points from GMM cluster 47: [1568, 728, 3194]
# Random points from GMM cluster 48: [2235, 540, 1818]
# Random points from GMM cluster 49: [870, 1750, 3099]
# Silhouette Coefficient: 0.1330791405962992

# %% [markdown]
# kmeans

# %%
 # K-means Clustering
for n in n_clusters:
            # Fit K-means to the data
            kmeans = KMeans(n_clusters=n)
            kmeans.fit(X)

            # Predict cluster labels
            labels = kmeans.labels_
            # Predict cluster labels
            labels = kmeans.predict(X)

            # Create a dictionary to store the cluster points
            cluster_points = {i: [] for i in range(n)}

            for i, label in enumerate(labels):
                cluster_points[label].append(i)

            # Print three random points from each cluster
            for cluster, points in cluster_points.items():
                random_points = random.sample(points, min(3, len(points)))
                print(f"Random points from KMM cluster {cluster}: {random_points}")

            # Calculate the Silhouette Coefficient
            silhouette_coefficient = silhouette_score(data, labels)
            print("Silhouette Coefficient:", silhouette_coefficient)

            # Apply PCA for visualization
            pca = PCA(n_components=2)
            X_pca = pca.fit_transform(X)

            # Plot the clusters
            plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis')
            plt.xlabel('Principal Component 1')
            plt.ylabel('Principal Component 2')
            plt.title(f'K-means Clustering with {n} clusters')
            plt.show()
# Out:
# Random points from KMM cluster 0: [756, 2, 3337]
# Random points from KMM cluster 1: [403, 2041, 2730]
# Silhouette Coefficient: 0.29573556596765077
# Random points from KMM cluster 0: [2146, 1683, 2193]
# Random points from KMM cluster 1: [2940, 1078, 234]
# Random points from KMM cluster 2: [154, 1096, 2534]
# Silhouette Coefficient: 0.26725267893975907
# Random points from KMM cluster 0: [3268, 1404, 78]
# Random points from KMM cluster 1: [81, 856, 883]
# Random points from KMM cluster 2: [3164, 2579, 2175]
# Random points from KMM cluster 3: [1393, 3334, 1530]
# Random points from KMM cluster 4: [1851, 2769, 1082]
# Random points from KMM cluster 5: [3052, 1461, 1782]
# Silhouette Coefficient: 0.214446552572064
# Random points from KMM cluster 0: [2394, 2445, 810]
# Random points from KMM cluster 1: [246, 1601, 2196]
# Random points from KMM cluster 2: [313, 3104, 841]
# Random points from KMM cluster 3: [697, 31, 2402]
# Random points from KMM cluster 4: [1807, 1382, 2329]
# Random points from KMM cluster 5: [419, 1535, 976]
# Random points from KMM cluster 6: [229, 411, 1566]
# Random points from KMM cluster 7: [161, 1885, 2433]
# Random points from KMM cluster 8: [132, 1455, 3387]
# Silhouette Coefficient: 0.2084872839494091
# Random points from KMM cluster 0: [1747, 584, 1549]
# Random points from KMM cluster 1: [223, 1151, 224]
# Random points from KMM cluster 2: [576, 500, 2553]
# Random points from KMM cluster 3: [2871, 1232, 3412]
# Random points from KMM cluster 4: [1097, 1801, 3035]
# Random points from KMM cluster 5: [2331, 1980, 2209]
# Random points from KMM cluster 6: [1022, 42, 1461]
# Random points from KMM cluster 7: [1048, 1800, 2882]
# Random points from KMM cluster 8: [2496, 3226, 1955]
# Random points from KMM cluster 9: [2581, 1617, 1416]
# Random points from KMM cluster 10: [2030, 970, 1475]
# Random points from KMM cluster 11: [1303, 2343, 3348]
# Random points from KMM cluster 12: [1868, 519, 485]
# Random points from KMM cluster 13: [2870, 1652, 2482]
# Random points from KMM cluster 14: [987, 908, 1607]
# Random points from KMM cluster 15: [3094, 2282, 238]
# Random points from KMM cluster 16: [824, 2591, 3106]
# Random points from KMM cluster 17: [2649, 1807, 1846]
# Random points from KMM cluster 18: [41, 2993, 1742]
# Random points from KMM cluster 19: [2941, 830, 1439]
# Random points from KMM cluster 20: [1977, 798, 3327]
# Random points from KMM cluster 21: [1795, 124, 698]
# Random points from KMM cluster 22: [140, 2386, 1739]
# Random points from KMM cluster 23: [2765, 3154, 1873]
# Random points from KMM cluster 24: [2925, 1851, 3326]
# Random points from KMM cluster 25: [3211, 1491, 428]
# Random points from KMM cluster 26: [1375, 2461, 1648]
# Random points from KMM cluster 27: [3, 1809, 2511]
# Random points from KMM cluster 28: [2430, 3006, 3052]
# Random points from KMM cluster 29: [3251, 1056, 2910]
# Random points from KMM cluster 30: [465, 2760, 666]
# Random points from KMM cluster 31: [3135, 797, 1885]
# Random points from KMM cluster 32: [2782, 906, 1284]
# Random points from KMM cluster 33: [2540, 178, 2501]
# Random points from KMM cluster 34: [1429, 1877, 410]
# Random points from KMM cluster 35: [1542, 1408, 1539]
# Random points from KMM cluster 36: [848, 1350, 60]
# Random points from KMM cluster 37: [2117, 2026, 870]
# Random points from KMM cluster 38: [644, 639, 113]
# Random points from KMM cluster 39: [172, 2784, 1431]
# Random points from KMM cluster 40: [2358, 1600, 1555]
# Random points from KMM cluster 41: [1131, 2394, 2548]
# Random points from KMM cluster 42: [1307, 2561, 176]
# Random points from KMM cluster 43: [2018, 296, 657]
# Random points from KMM cluster 44: [1198, 1583, 1341]
# Random points from KMM cluster 45: [649, 602, 2622]
# Random points from KMM cluster 46: [599, 1, 110]
# Random points from KMM cluster 47: [1077, 561, 2008]
# Random points from KMM cluster 48: [501, 1943, 1519]
# Random points from KMM cluster 49: [3225, 1091, 1828]
# Silhouette Coefficient: 0.13352637844941043

# %% [markdown]
# HAC

# %%
    # Hierarchical Clustering
for n in n_clusters:
        # Perform hierarchical clustering
        linkage = hierarchy.linkage(X, method='ward')
        labels = hierarchy.cut_tree(linkage, n_clusters=n).flatten()

        # Create a dictionary to store the cluster points
        cluster_points = {i: [] for i in range(n)}

        for i, label in enumerate(labels):
            cluster_points[label].append(i)

        # Print three random points from each cluster
        for cluster, points in cluster_points.items():
            random_points = random.sample(points, min(3, len(points)))
            print(f"Random points from HAC cluster {cluster}: {random_points}")

        # Calculate the Silhouette Coefficient
        silhouette_coefficient = silhouette_score(data, labels)
        print("Silhouette Coefficient:", silhouette_coefficient)

        # Apply PCA for visualization
        pca = PCA(n_components=2)
        X_pca = pca.fit_transform(X)


        # Plot the clusters
        plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis')
        plt.xlabel('Principal Component 1')
        plt.ylabel('Principal Component 2')
        plt.title(f'Hierarchical Clustering with {n} clusters')
        plt.show()
# Out:
# Random points from HAC cluster 0: [1583, 1630, 1486]
# Random points from HAC cluster 1: [1370, 2385, 577]
# Silhouette Coefficient: 0.2955356816384406
# Random points from HAC cluster 0: [2426, 783, 14]
# Random points from HAC cluster 1: [944, 1462, 1145]
# Random points from HAC cluster 2: [821, 2044, 615]
# Silhouette Coefficient: 0.2364397393591947
# Random points from HAC cluster 0: [1688, 1492, 2411]
# Random points from HAC cluster 1: [259, 1626, 1719]
# Random points from HAC cluster 2: [364, 355, 360]
# Random points from HAC cluster 3: [36, 1782, 2120]
# Random points from HAC cluster 4: [2736, 1729, 97]
# Random points from HAC cluster 5: [2817, 755, 3094]
# Silhouette Coefficient: 0.2134414454998834
# Random points from HAC cluster 0: [2467, 1848, 884]
# Random points from HAC cluster 1: [2590, 825, 2976]
# Random points from HAC cluster 2: [176, 338, 62]
# Random points from HAC cluster 3: [2284, 2954, 273]
# Random points from HAC cluster 4: [3297, 1793, 2764]
# Random points from HAC cluster 5: [1837, 3133, 356]
# Random points from HAC cluster 6: [1199, 2226, 1537]
# Random points from HAC cluster 7: [1040, 2364, 2711]
# Random points from HAC cluster 8: [2282, 1236, 1639]
# Silhouette Coefficient: 0.14709258291763747
# Random points from HAC cluster 0: [2116, 1653, 2509]
# Random points from HAC cluster 1: [673, 2288, 2291]
# Random points from HAC cluster 2: [2557, 3071, 1623]
# Random points from HAC cluster 3: [2948, 2224, 2410]
# Random points from HAC cluster 4: [1379, 2710, 2145]
# Random points from HAC cluster 5: [867, 653, 1243]
# Random points from HAC cluster 6: [1082, 739, 1916]
# Random points from HAC cluster 7: [2357, 42, 765]
# Random points from HAC cluster 8: [2827, 246, 3304]
# Random points from HAC cluster 9: [2094, 2267, 1026]
# Random points from HAC cluster 10: [2939, 2800, 1283]
# Random points from HAC cluster 11: [2232, 1569, 92]
# Random points from HAC cluster 12: [2156, 2165, 1565]
# Random points from HAC cluster 13: [1621, 1672, 3142]
# Random points from HAC cluster 14: [2254, 2117, 721]
# Random points from HAC cluster 15: [1731, 781, 1966]
# Random points from HAC cluster 16: [1463, 175, 321]
# Random points from HAC cluster 17: [941, 296, 244]
# Random points from HAC cluster 18: [3301, 2514, 713]
# Random points from HAC cluster 19: [2025, 1170, 1492]
# Random points from HAC cluster 20: [2239, 2292, 2011]
# Random points from HAC cluster 21: [28, 1198, 1583]
# Random points from HAC cluster 22: [634, 230, 900]
# Random points from HAC cluster 23: [586, 1712, 1887]
# Random points from HAC cluster 24: [1328, 3337, 2477]
# Random points from HAC cluster 25: [2946, 1242, 415]
# Random points from HAC cluster 26: [2692, 913, 2004]
# Random points from HAC cluster 27: [2437, 1822, 3263]
# Random points from HAC cluster 28: [3068, 3078, 817]
# Random points from HAC cluster 29: [56, 830, 824]
# Random points from HAC cluster 30: [1436, 3200, 1893]
# Random points from HAC cluster 31: [161, 2206, 1291]
# Random points from HAC cluster 32: [2945, 2151, 2633]
# Random points from HAC cluster 33: [2613, 395, 1186]
# Random points from HAC cluster 34: [2848, 313, 621]
# Random points from HAC cluster 35: [3310, 331, 1669]
# Random points from HAC cluster 36: [1014, 2898, 165]
# Random points from HAC cluster 37: [419, 3328, 722]
# Random points from HAC cluster 38: [1413, 1542, 3031]
# Random points from HAC cluster 39: [1284, 791, 2486]
# Random points from HAC cluster 40: [2646, 2436, 2430]
# Random points from HAC cluster 41: [1048, 2447, 748]
# Random points from HAC cluster 42: [2554, 1579, 599]
# Random points from HAC cluster 43: [2049, 2534, 468]
# Random points from HAC cluster 44: [2731, 2187, 448]
# Random points from HAC cluster 45: [560, 755, 1193]
# Random points from HAC cluster 46: [1100, 2904, 1842]
# Random points from HAC cluster 47: [1127, 968, 630]
# Random points from HAC cluster 48: [2925, 1851, 3326]
# Random points from HAC cluster 49: [2105, 2875, 2238]
# Silhouette Coefficient: 0.09039476343622992

# %% [markdown]
# # Clustering wiht Extracted Features

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from scipy.cluster import hierarchy
import random

# %%
# Read the feature data from CSV
data = pd.read_csv('feature_extraction_data_analysis.csv')
X = data.iloc[:,1:43].values

# Perform clustering with different numbers of clusters
n_clusters = [2, 3, 6, 9, 50]

# %% [markdown]
# GMM

# %%
for n in n_clusters:
    # Fit GMM to the data
    gmm = GaussianMixture(n_components=n)
    gmm.fit(X)

    # Predict cluster labels
    labels = gmm.predict(X)

    # Create a dictionary to store the cluster points
    cluster_points = {i: [] for i in range(n)}

    for i, label in enumerate(labels):
        cluster_points[label].append(i)

    # Print three random points from each cluster
    for cluster, points in cluster_points.items():
        random_points = random.sample(points, min(3, len(points)))
        print(f"Random points from GMM cluster {cluster}: {random_points}")

    # Calculate the Silhouette Coefficient
    silhouette_coefficient = silhouette_score(X, labels)
    print("Silhouette Coefficient:", silhouette_coefficient)

    # Apply PCA for visualization
    pca = PCA(n_components=2)
    X_pca = pca.fit_transform(X)

    # Plot the clusters
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis')
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.title(f'GMM Clustering with {n} clusters')
    plt.show()
# Out:
# Random points from GMM cluster 0: [1785, 3130, 3024]
# Random points from GMM cluster 1: [648, 426, 849]
# Silhouette Coefficient: 0.127005622636531
# Random points from GMM cluster 0: [2595, 1267, 546]
# Random points from GMM cluster 1: [2053, 87, 2313]
# Random points from GMM cluster 2: [2453, 554, 160]
# Silhouette Coefficient: 0.09792406018529472
# Random points from GMM cluster 0: [2763, 446, 1594]
# Random points from GMM cluster 1: [1234, 1384, 2679]
# Random points from GMM cluster 2: [433, 485, 206]
# Random points from GMM cluster 3: [489, 3348, 2725]
# Random points from GMM cluster 4: [3405, 1465, 3138]
# Random points from GMM cluster 5: [2660, 2983, 2385]
# Silhouette Coefficient: 0.06681080845177083
# Random points from GMM cluster 0: [2802, 101, 2170]
# Random points from GMM cluster 1: [86, 102, 1888]
# Random points from GMM cluster 2: [3208, 737, 1668]
# Random points from GMM cluster 3: [835, 1932, 611]
# Random points from GMM cluster 4: [1901, 3258, 2448]
# Random points from GMM cluster 5: [506, 1784, 674]
# Random points from GMM cluster 6: [1312, 1997, 1354]
# Random points from GMM cluster 7: [2462, 1748, 2719]
# Random points from GMM cluster 8: [2798, 3302, 1924]
# Silhouette Coefficient: 0.05714674407414004
# Random points from GMM cluster 0: [1419, 2236, 1540]
# Random points from GMM cluster 1: [2812, 1641, 1854]
# Random points from GMM cluster 2: [2205, 2070, 2289]
# Random points from GMM cluster 3: [1470, 2163, 3068]
# Random points from GMM cluster 4: [2573, 1972, 2934]
# Random points from GMM cluster 5: [2778, 1618, 1471]
# Random points from GMM cluster 6: [2002, 1168, 1300]
# Random points from GMM cluster 7: [591, 352, 622]
# Random points from GMM cluster 8: [2717, 1375, 3219]
# Random points from GMM cluster 9: [3144, 2246, 2666]
# Random points from GMM cluster 10: [1394, 626, 397]
# Random points from GMM cluster 11: [3343, 2990, 2066]
# Random points from GMM cluster 12: [794, 1586, 2276]
# Random points from GMM cluster 13: [2911, 195, 1835]
# Random points from GMM cluster 14: [400, 2278, 2987]
# Random points from GMM cluster 15: [1388, 2054, 720]
# Random points from GMM cluster 16: [1996, 1549]
# Random points from GMM cluster 17: [219, 2805, 2881]
# Random points from GMM cluster 18: [151, 1, 1575]
# Random points from GMM cluster 19: [2406, 2587, 3178]
# Random points from GMM cluster 20: [1823, 3413, 11]
# Random points from GMM cluster 21: [939, 1596, 248]
# Random points from GMM cluster 22: [1766, 1484, 441]
# Random points from GMM cluster 23: [2225, 877, 2509]
# Random points from GMM cluster 24: [1800, 3036, 784]
# Random points from GMM cluster 25: [2050, 583, 3217]
# Random points from GMM cluster 26: [1183, 1981, 865]
# Random points from GMM cluster 27: [3201, 267, 1842]
# Random points from GMM cluster 28: [438, 1958, 2825]
# Random points from GMM cluster 29: [2092, 3409, 2949]
# Random points from GMM cluster 30: [1546, 1635, 3060]
# Random points from GMM cluster 31: [2590, 1733, 2151]
# Random points from GMM cluster 32: [1353, 16, 1622]
# Random points from GMM cluster 33: [413, 1504, 2128]
# Random points from GMM cluster 34: [2563, 1807, 619]
# Random points from GMM cluster 35: [2010, 3355, 2046]
# Random points from GMM cluster 36: [1360, 2486, 2154]
# Random points from GMM cluster 37: [2719, 485, 1581]
# Random points from GMM cluster 38: [741, 2899, 1408]
# Random points from GMM cluster 39: [1090, 959, 72]
# Random points from GMM cluster 40: [9, 1346, 3344]
# Random points from GMM cluster 41: [755, 516, 2502]
# Random points from GMM cluster 42: [3271, 3270, 8]
# Random points from GMM cluster 43: [2689, 96, 260]
# Random points from GMM cluster 44: [2016]
# Random points from GMM cluster 45: [2226, 887, 3034]
# Random points from GMM cluster 46: [135, 855, 348]
# Random points from GMM cluster 47: [2859, 1042, 205]
# Random points from GMM cluster 48: [1862, 2039, 2191]
# Random points from GMM cluster 49: [1571, 1347, 1349]
# Silhouette Coefficient: 0.08669459893946006

# %% [markdown]
# kmeans

# %%
for n in n_clusters:
            # Fit K-means to the data
            kmeans = KMeans(n_clusters=n)
            kmeans.fit(X)

            # Predict cluster labels
            labels = kmeans.labels_
            # Predict cluster labels
            labels = kmeans.predict(X)

            # Create a dictionary to store the cluster points
            cluster_points = {i: [] for i in range(n)}

            for i, label in enumerate(labels):
                cluster_points[label].append(i)

            # Print three random points from each cluster
            for cluster, points in cluster_points.items():
                random_points = random.sample(points, min(3, len(points)))
                print(f"Random points from KMM cluster {cluster}: {random_points}")

            # Calculate the Silhouette Coefficient
            silhouette_coefficient = silhouette_score(X, labels)
            print("Silhouette Coefficient:", silhouette_coefficient)

            # Apply PCA for visualization
            pca = PCA(n_components=2)
            X_pca = pca.fit_transform(X)

            # Plot the clusters
            plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis')
            plt.xlabel('Principal Component 1')
            plt.ylabel('Principal Component 2')
            plt.title(f'K-means Clustering with {n} clusters')
            plt.show()
# Out:
# Random points from KMM cluster 0: [3299, 826, 2550]
# Random points from KMM cluster 1: [333, 3219, 416]
# Silhouette Coefficient: 0.17675803769088835
# Random points from KMM cluster 0: [33, 1641, 1386]
# Random points from KMM cluster 1: [749, 2934, 2590]
# Random points from KMM cluster 2: [2068, 3034, 880]
# Silhouette Coefficient: 0.13430454264184338
# Random points from KMM cluster 0: [1058, 159, 1207]
# Random points from KMM cluster 1: [2132, 2287, 3151]
# Random points from KMM cluster 2: [2766, 3332, 1073]
# Random points from KMM cluster 3: [1510, 2867, 1982]
# Random points from KMM cluster 4: [2901, 2879, 2722]
# Random points from KMM cluster 5: [2210, 992, 2896]
# Silhouette Coefficient: 0.1198438668066176
# Random points from KMM cluster 0: [1706, 2149, 232]
# Random points from KMM cluster 1: [2055, 353, 3338]
# Random points from KMM cluster 2: [3123, 743, 3335]
# Random points from KMM cluster 3: [228, 844, 2227]
# Random points from KMM cluster 4: [1188, 2076, 3341]
# Random points from KMM cluster 5: [1506, 2669, 497]
# Random points from KMM cluster 6: [3384, 2458, 1731]
# Random points from KMM cluster 7: [1394, 2957, 1015]
# Random points from KMM cluster 8: [1854, 636, 427]
# Silhouette Coefficient: 0.10993040062996216
# Random points from KMM cluster 0: [44, 3028, 3115]
# Random points from KMM cluster 1: [1832, 438, 1861]
# Random points from KMM cluster 2: [92, 1118, 1610]
# Random points from KMM cluster 3: [1444, 3094, 1052]
# Random points from KMM cluster 4: [3356, 3010, 1726]
# Random points from KMM cluster 5: [2276, 523, 1692]
# Random points from KMM cluster 6: [1959, 1098, 634]
# Random points from KMM cluster 7: [2314, 1640, 2089]
# Random points from KMM cluster 8: [1778, 2563, 3092]
# Random points from KMM cluster 9: [3044, 2012, 780]
# Random points from KMM cluster 10: [511, 120, 1489]
# Random points from KMM cluster 11: [757, 1893, 285]
# Random points from KMM cluster 12: [2743, 321, 2383]
# Random points from KMM cluster 13: [1548, 2771, 3333]
# Random points from KMM cluster 14: [2786, 2094, 1855]
# Random points from KMM cluster 15: [800, 3288, 1939]
# Random points from KMM cluster 16: [2297, 2838, 479]
# Random points from KMM cluster 17: [3341, 3357, 3215]
# Random points from KMM cluster 18: [1996]
# Random points from KMM cluster 19: [2015, 2550, 2523]
# Random points from KMM cluster 20: [2016]
# Random points from KMM cluster 21: [3268, 834, 1787]
# Random points from KMM cluster 22: [1233, 2999, 825]
# Random points from KMM cluster 23: [487, 1270, 1347]
# Random points from KMM cluster 24: [2028, 55, 2708]
# Random points from KMM cluster 25: [2606, 3088, 3077]
# Random points from KMM cluster 26: [1421, 3105, 505]
# Random points from KMM cluster 27: [1070, 483, 582]
# Random points from KMM cluster 28: [613, 2956, 972]
# Random points from KMM cluster 29: [455, 158, 245]
# Random points from KMM cluster 30: [1130, 644, 3009]
# Random points from KMM cluster 31: [2914, 3, 1338]
# Random points from KMM cluster 32: [1376, 220, 504]
# Random points from KMM cluster 33: [2218, 896, 417]
# Random points from KMM cluster 34: [764, 2367, 1040]
# Random points from KMM cluster 35: [2852, 64, 1279]
# Random points from KMM cluster 36: [283, 2355, 3013]
# Random points from KMM cluster 37: [1549]
# Random points from KMM cluster 38: [1408, 1657, 1400]
# Random points from KMM cluster 39: [2882, 1217, 1593]
# Random points from KMM cluster 40: [2893, 2736, 1555]
# Random points from KMM cluster 41: [2017, 2615, 3281]
# Random points from KMM cluster 42: [806, 27, 3349]
# Random points from KMM cluster 43: [2037, 2275, 687]
# Random points from KMM cluster 44: [191, 2936, 839]
# Random points from KMM cluster 45: [958, 753, 3355]
# Random points from KMM cluster 46: [1970, 433, 2151]
# Random points from KMM cluster 47: [374, 584, 1525]
# Random points from KMM cluster 48: [2421, 793, 3313]
# Random points from KMM cluster 49: [2240, 28, 87]
# Silhouette Coefficient: 0.09398875086085731

# %% [markdown]
# HAC

# %%
# Hierarchical Clustering
for n in n_clusters:
    # Perform hierarchical clustering
    linkage = hierarchy.linkage(X, method='ward')
    labels = hierarchy.cut_tree(linkage, n_clusters=n).flatten()

    # Apply PCA for visualization
    pca = PCA(n_components=2)
    X_pca = pca.fit_transform(X)

    # Create a dictionary to store the cluster points
    cluster_points = {i: [] for i in range(n)}

    for i, label in enumerate(labels):
        cluster_points[label].append(i)

    # Print three random points from each cluster
    for cluster, points in cluster_points.items():
        random_points = random.sample(points, min(3, len(points)))
        print(f"Random points from HAC cluster {cluster}: {random_points}")

            # Calculate the Silhouette Coefficient
    silhouette_coefficient = silhouette_score(X, labels)
    print("Silhouette Coefficient:", silhouette_coefficient)

    # Plot the clusters
    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis')
    plt.xlabel('Principal Component 1')
    plt.ylabel('Principal Component 2')
    plt.title(f'Hierarchical Clustering with {n} clusters')
    plt.show()
# Out:
# Random points from HAC cluster 0: [1474, 1413, 2882]
# Random points from HAC cluster 1: [3158, 3233, 2353]
# Silhouette Coefficient: 0.1910124973054485
# Random points from HAC cluster 0: [2887, 1456, 1579]
# Random points from HAC cluster 1: [3046, 1034, 1556]
# Random points from HAC cluster 2: [2202, 849, 1994]
# Silhouette Coefficient: 0.09624428911611561
# Random points from HAC cluster 0: [121, 1772, 2524]
# Random points from HAC cluster 1: [2973, 347, 2064]
# Random points from HAC cluster 2: [1232, 402, 2449]
# Random points from HAC cluster 3: [2423, 3307, 2425]
# Random points from HAC cluster 4: [2904, 973, 471]
# Random points from HAC cluster 5: [3007, 286, 1985]
# Silhouette Coefficient: 0.07301656470330403
# Random points from HAC cluster 0: [1895, 2281, 1487]
# Random points from HAC cluster 1: [783, 2228, 2617]
# Random points from HAC cluster 2: [977, 127, 2355]
# Random points from HAC cluster 3: [163, 1385, 2392]
# Random points from HAC cluster 4: [2189, 718, 794]
# Random points from HAC cluster 5: [380, 2065, 2529]
# Random points from HAC cluster 6: [2827, 685, 1477]
# Random points from HAC cluster 7: [2368, 2568, 1180]
# Random points from HAC cluster 8: [1549, 1996]
# Silhouette Coefficient: 0.06503062295987673
# Random points from HAC cluster 0: [121, 2821, 180]
# Random points from HAC cluster 1: [2725, 186, 2499]
# Random points from HAC cluster 2: [1319, 2875, 1903]
# Random points from HAC cluster 3: [1190, 1892, 2208]
# Random points from HAC cluster 4: [1583, 1491, 699]
# Random points from HAC cluster 5: [1731, 253, 1256]
# Random points from HAC cluster 6: [2985, 430, 1364]
# Random points from HAC cluster 7: [750, 1592, 495]
# Random points from HAC cluster 8: [1601, 16, 2676]
# Random points from HAC cluster 9: [2703, 709, 757]
# Random points from HAC cluster 10: [1771, 1142, 1924]
# Random points from HAC cluster 11: [1891, 2416, 1481]
# Random points from HAC cluster 12: [1286, 21, 1165]
# Random points from HAC cluster 13: [487, 1209, 1347]
# Random points from HAC cluster 14: [1163, 801, 877]
# Random points from HAC cluster 15: [176, 1077, 237]
# Random points from HAC cluster 16: [770, 1981, 445]
# Random points from HAC cluster 17: [2252, 31, 2200]
# Random points from HAC cluster 18: [2136, 2138, 572]
# Random points from HAC cluster 19: [1700, 2263, 233]
# Random points from HAC cluster 20: [3173, 2889, 359]
# Random points from HAC cluster 21: [44, 488, 1436]
# Random points from HAC cluster 22: [1088, 2576, 62]
# Random points from HAC cluster 23: [1634, 2862, 440]
# Random points from HAC cluster 24: [1603, 310, 2419]
# Random points from HAC cluster 25: [2269, 2834, 3403]
# Random points from HAC cluster 26: [2957, 2171, 1334]
# Random points from HAC cluster 27: [448, 2563, 865]
# Random points from HAC cluster 28: [2370, 2223, 2490]
# Random points from HAC cluster 29: [1030, 2670, 2081]
# Random points from HAC cluster 30: [1913, 944, 1559]
# Random points from HAC cluster 31: [1563, 272, 1384]
# Random points from HAC cluster 32: [2808, 356, 1897]
# Random points from HAC cluster 33: [2501, 2128, 2984]
# Random points from HAC cluster 34: [281, 3379, 726]
# Random points from HAC cluster 35: [2987, 94, 1128]
# Random points from HAC cluster 36: [732, 2519, 704]
# Random points from HAC cluster 37: [2643, 3007, 3211]
# Random points from HAC cluster 38: [2238, 1393, 2542]
# Random points from HAC cluster 39: [156, 366, 3138]
# Random points from HAC cluster 40: [2533, 1803, 3253]
# Random points from HAC cluster 41: [2634, 2002, 2930]
# Random points from HAC cluster 42: [221, 3312, 1694]
# Random points from HAC cluster 43: [2183, 2422, 1658]
# Random points from HAC cluster 44: [1825, 2366, 1615]
# Random points from HAC cluster 45: [1226, 2305, 493]
# Random points from HAC cluster 46: [753, 958, 2046]
# Random points from HAC cluster 47: [1726, 2994, 3270]
# Random points from HAC cluster 48: [1549, 1996]
# Random points from HAC cluster 49: [2016]
# Silhouette Coefficient: 0.046171585455695545
